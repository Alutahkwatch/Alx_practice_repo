# %% [markdown]
# <a href="https://colab.research.google.com/github/Alutahkwatch/Alx_practice_repo/blob/main/voice_style_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saurabhv749/supertonic3-voice-clone.git /content/cloner
# !cd /content/cloner && source ./setup.sh
# Out:
# Cloning into '/content/cloner'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 73 (delta 26), reused 61 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 3.15 MiB | 28.82 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 668.2/668.2 kB 18.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.16.1
#     Uninstalling huggingface_hub-1.16.1:
#       Successfully uninstalled huggingface_hub-1.16.1
# ...
# /content/cloner/supertonic3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 845.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 53.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/cloner

# EDIT: configs/default.json
# !python train_style.py
# Out:
# /content/cloner
# ...
# hyperparams.yaml: 100% 1.92k/1.92k [00:00<00:00, 6.67MB/s]
# embedding_model.ckpt: 100% 83.3M/83.3M [00:00<00:00, 84.9MB/s]
# mean_var_norm_emb.ckpt: 100% 1.92k/1.92k [00:00<00:00, 12.6MB/s]
# classifier.ckpt: 100% 5.53M/5.53M [00:00<00:00, 19.9MB/s]
# label_encoder.txt: 100% 129k/129k [00:00<00:00, 62.2MB/s]
# Loaded: voices/F6.wav | Duration: 14.69s
#
# [utils.model]: Converting ONNX models to PyTorch...
# [utils.model]: ✅ All models converted to PyTorch.
# Using CPU for inference
# Using device: cuda
# Name: F6
# ...

# %% [markdown]
# ### Generation

# %%
# !python generate.py \
--text "You also make humanoid robots now, which look exactly like people, except they don’t have faces or feelings or a crippling fear of dying." \
--style "/content/cloner/logs/F6/F6_0500.json"
# Out:
# Using CPU for inference
# /usr/local/lib/python3.12/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:149: UserWarning: Specified provider 'DmlExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Loaded 1 voice styles
#
# === Generating speech for text: 'You also make humanoid robots now, which look exactly like people, except they don’t have faces or feelings or a crippling fear of dying.' with voice style: 'F6_0500' ===
# Generating speech from text...
#   -> Generating speech from text completed in 3.39 sec
#
# === Synthesis completed successfully! ===
# Saved: samples/F6_0500_1778880810.wav

# %%
from IPython.display import Audio
Audio('/content/cloner/samples/F6_0500_1778880810.wav')
